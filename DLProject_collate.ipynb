# %%
import json
with open('/content/drive/MyDrive/DL/final_project/pix2code/history_hp2.json','r') as f:
  hp2=json.load(f)

# %%
with open('/content/drive/MyDrive/DL/final_project/pix2code/history_hp3.json','r') as f:
  hp3=json.load(f)

# %%
with open('/content/drive/MyDrive/DL/final_project/pix2code/history_hp1.json','r') as f:
  hp1=json.load(f)

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Training Loss vs. Epochs")
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.plot(hp1['loss'],label="hypothesis 1")
plt.plot(hp2['loss'],label="hypothesis 2")
plt.plot(hp3['loss'],label="hypothesis 3")
leg = plt.legend(loc='upper right')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.title("Training Loss vs. Epochs")
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.plot(hp1['loss'][1:],label="hypothesis 1")
plt.plot(hp2['loss'][1:],label="hypothesis 2")
plt.plot(hp3['loss'][1:],label="hypothesis 3")
leg = plt.legend(loc='upper right')

# %%
plt.title("Training perplexity vs. Epochs")
plt.ylabel('Perplexity')
plt.xlabel('Number of epochs')
plt.plot(hp1['perp'],label="hypothesis 1")
plt.plot(hp2['perp'],label="hypothesis 2")
plt.plot(hp3['perp'],label="hypothesis 3")
leg = plt.legend(loc='upper right')

# %%
plt.title("Training perplexity vs. Epochs")
plt.ylabel('Perplexity')
plt.xlabel('Number of epochs')
plt.plot(hp1['perp'][1:],label="hypothesis 1")
plt.plot(hp2['perp'][1:],label="hypothesis 2")
plt.plot(hp3['perp'][1:],label="hypothesis 3")
leg = plt.legend(loc='upper right')

# %%
time_dict={'Hypothesis 1':hp1['time'][-1]-hp1['time'][0], 'Hypothesis 2':hp2['time'][-1],'Hypothesis 3':hp3['time'][-1]-hp3['time'][0]}

# %%
import matplotlib.pyplot as plt
 
  
# creating the dataset
data = time_dict
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
# plt.xlabel("Hypothesis")
plt.ylabel("Time in seonds")
plt.title("Time taken for convergence")
plt.show()

# %%
hyp2_bleu_val  = [('2-1', 0.6821744511881205),
 ('4-1', 0.6830318112673441),
 ('6-1', 0.675798928641526),
 ('8-1', 0.6765190789158899),
 ('10-1', 0.6771639003037694)]

# %%
hyp2_vals = [v[1] for v in hyp2_bleu_val]

# %%
plt.title("bleu score vs. Epochs")
plt.ylabel('bleu score')
plt.xlabel('Number of epochs')
plt.plot(hyp2_vals)
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
hyp3_bleu_val = [('2-1', 0.6727577127730313),
 ('4-1', 0.6610520548849329),
 ('6-1', 0.6597872324321675),
 ('8-1', 0.6577530621330517),
 ('10-1', 0.6430789998994517)]

# %%
hyp3_vals = [v[1] for v in hyp3_bleu_val]

# %%
plt.title("bleu score vs. Epochs")
plt.ylabel('bleu score')
plt.xlabel('Number of epochs')
plt.plot(hyp3_vals)
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
plt.title("Training Loss vs. Epochs")
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.plot(hp1['loss'])
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
plt.title("Training Loss vs. Epochs")
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.plot(hp2['loss'])
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
plt.title("Training Loss vs. Epochs")
plt.ylabel('Loss')
plt.xlabel('Number of epochs')
plt.plot(hp3['loss'])
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
plt.title("Perplexity vs. Epochs")
plt.ylabel('Perplexity')
plt.xlabel('Number of epochs')
plt.plot(hp1['perp'])
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
plt.title("Perplexity vs. Epochs")
plt.ylabel('Perplexity')
plt.xlabel('Number of epochs')
plt.plot(hp2['perp'])
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.

# %%
plt.title("Perplexity vs. Epochs")
plt.ylabel('Perplexity')
plt.xlabel('Number of epochs')
plt.plot(hp3['perp'])
leg = plt.legend(loc='upper right')
# Out:
# No handles with labels found to put in legend.
